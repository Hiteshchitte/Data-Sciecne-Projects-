# %% [markdown]
# # Final Project Part - II DUE: 11:59pm Friday Dec. 16, 2023
# ## (No late submissions accepted)
#
# ### In this part II, you will be performing different analytics using the related "cc_" tables and data you created in your postgres SSO dsa_student database in Part I.
#
# You will be designing and executing a variety of queries on the Chicago crime database tables - hints included.
#
# It is your choice how you connect to your dsa_student SSO database and successfully implement the queries for each question.

# %%
#CONNETION HERE
import getpass
mypasswd = getpass.getpass()
username = 'hc3ng'
host = 'pgsql.dsa.lan'
database = 'dsa_student'

# %reload_ext sql
# %sql postgres://hc3ng:{mypasswd}@pgsql.dsa.lan/dsa_student
# Out:
# ········
# 'Connected: hc3ng@dsa_student'

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# ### 1- Construct a query to retrieve a count of the primary descriptions of case incidents for all years in descending order.
# <span style="font-size:7px"><b>Hint:</b> 26 rows affected -- data[PUBLIC PEACE VIOLATION=21021]</span>

# %%
# %%sql
#
# SELECT COUNT (iucr_primary_desc), iucr_primary_desc
# FROM  cc_iucr_codes_primary_descriptions
# JOIN cc_cases USING (iucr_code)
# GROUP BY iucr_primary_desc
# ORDER BY COUNT (iucr_primary_desc) DESC;
# Out:
#  * postgres://hc3ng:***@pgsql.dsa.lan/dsa_student
# 26 rows affected.
# [(875324, 'CRIMINAL DAMAGE'),
#  (744549, 'NARCOTICS'),
#  (476687, 'OTHER OFFENSE'),
#  (336587, 'DECEPTIVE PRACTICE'),
#  (212364, 'CRIMINAL TRESPASS'),
#  (113063, 'ROBBERY'),
#  (102966, 'WEAPONS VIOLATION'),
#  (69734, 'PROSTITUTION'),
#  (63839, 'ASSAULT'),
#  (54742, 'OFFENSE INVOLVING CHILDREN'),
#  (46548, 'BATTERY'),
#  (29273, 'SEX OFFENSE'),
#  (21021, 'PUBLIC PEACE VIOLATION'),
#  (18168, 'INTERFERENCE WITH PUBLIC OFFICER'),
#  (14826, 'LIQUOR LAW VIOLATION'),
#  (14616, 'GAMBLING'),
#  (13072, 'ARSON'),
#  (7171, 'KIDNAPPING'),
#  (4547, 'INTIMIDATION'),
#  (999, 'CONCEALED CARRY LICENSE VIOLATION'),
#  (794, 'OBSCENITY'),
#  (231, 'OTHER OFFENSE '),
#  (193, 'PUBLIC INDECENCY'),
#  (145, 'OTHER NARCOTIC VIOLATION'),
#  (97, 'HUMAN TRAFFICKING'),
#  (16, 'NON-CRIMINAL')]

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# ### 2- Construct a query to retrieve a count of the primary descriptions of case incidents for all years with arrest being TRUE in descending order.
# <span style="font-size:7px"><b>Hint:</b> 26 rows affected -- data[ARSON=1623]</span>

# %%
# %%sql
#
# SELECT COUNT (iucr_primary_desc), iucr_primary_desc
# FROM cc_iucr_codes_primary_descriptions
# JOIN cc_cases USING (iucr_code)
# WHERE arrest = 1
# GROUP BY iucr_primary_desc
# ORDER BY COUNT (iucr_primary_desc)
# DESC;
# Out:
#  * postgres://hc3ng:***@pgsql.dsa.lan/dsa_student
# 26 rows affected.
# [(740094, 'NARCOTICS'),
#  (149695, 'CRIMINAL TRESPASS'),
#  (83792, 'OTHER OFFENSE'),
#  (76861, 'WEAPONS VIOLATION'),
#  (69462, 'PROSTITUTION'),
#  (59166, 'CRIMINAL DAMAGE'),
#  (46043, 'DECEPTIVE PRACTICE'),
#  (16712, 'INTERFERENCE WITH PUBLIC OFFICER'),
#  (15253, 'ASSAULT'),
#  (14699, 'LIQUOR LAW VIOLATION'),
#  (14509, 'GAMBLING'),
#  (10907, 'OFFENSE INVOLVING CHILDREN'),
#  (8257, 'SEX OFFENSE'),
#  (7512, 'ROBBERY'),
#  (6285, 'PUBLIC PEACE VIOLATION'),
#  (3762, 'BATTERY'),
#  (1623, 'ARSON'),
#  (965, 'CONCEALED CARRY LICENSE VIOLATION'),
#  (779, 'KIDNAPPING'),
#  (714, 'INTIMIDATION'),
#  (629, 'OBSCENITY'),
#  (191, 'PUBLIC INDECENCY'),
#  (100, 'OTHER NARCOTIC VIOLATION'),
#  (52, 'OTHER OFFENSE '),
#  (9, 'HUMAN TRAFFICKING'),
#  (5, 'NON-CRIMINAL')]

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# ### 3- Construct a query to retrieve the count of case incidents, count and percent (rounded to 3 decimal places) of arrests for each year;  order descending by arrested percent.
# <span style="font-size:7px"><b>Hint:</b> 22 rows affected -- data[2015=26.451%] -- parse dates, uses "case when"</span>

# %%
# %%sql
# SELECT CAST(EXTRACT(YEAR FROM incident_date)AS INT) AS Year,
# COUNT (case_number) AS incident_case,
# SUM(case WHEN arrest = 1 then 1 ELSE NULL END),
# ROUND(100* (CAST(SUM(case when arrest =1 then 1 ELSE NULL END) AS FLOAT)/COUNT(case_number))::numeric, 3) AS Percentage_Arrest
# FROM cc_cases
# GROUP BY Year
# ORDER BY Percentage_arrest DESC;
# Out:
#  * postgres://hc3ng:***@pgsql.dsa.lan/dsa_student
# 22 rows affected.
# [(2005, 453754, 140914, Decimal('31.055')),
#  (2004, 469406, 144692, Decimal('30.824')),
#  (2006, 448151, 135404, Decimal('30.214')),
#  (2007, 437060, 131862, Decimal('30.170')),
#  (2003, 475943, 141563, Decimal('29.744')),
#  (2001, 485832, 141913, Decimal('29.210')),
#  (2002, 486776, 141553, Decimal('29.080')),
#  (2014, 275705, 79614, Decimal('28.877')),
#  (2009, 392796, 110811, Decimal('28.211')),
#  (2013, 307430, 86525, Decimal('28.145')),
#  (2011, 351932, 96266, Decimal('27.354')),
#  (2010, 370455, 100511, Decimal('27.132')),
#  (2012, 336221, 90638, Decimal('26.958')),
#  (2015, 264682, 70011, Decimal('26.451')),
#  (2008, 427132, 109991, Decimal('25.751')),
#  (2019, 261129, 56167, Decimal('21.509')),
#  (2018, 268664, 53827, Decimal('20.035')),
#  (2016, 269723, 52993, Decimal('19.647')),
#  (2017, 268958, 52613, Decimal('19.562')),
#  (2020, 211908, 34035, Decimal('16.061')),
#  (2021, 207925, 25863, Decimal('12.439')),
#  (2022, 204959, 23078, Decimal('11.260'))]

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# ### 4- Construct a query to retrieve the list of iucr codes and index code with their matching primary and secondary descriptions that do not appear as an iucr code for the cases.
# <span style="font-size:7px"><b>Hint:</b> 117 rows affected -- data[261,I,CRIM SEXUAL ASSAULT,AGGRAVATED: HANDGUN]</span>

# %%
# %%sql
#
# SELECT iucr_primary_desc, iucr_secondary_desc, iucr_index_code, iucr_code
# FROM cc_iucr_codes
# JOIN cc_iucr_codes_primary_descriptions USING (iucr_code)
# JOIN cc_iucr_codes_secondary_descriptions USING (iucr_code)
# WHERE iucr_code NOT IN (SELECT iucr_code FROM cc_cases)
# LIMIT 200;
# Out:
#  * postgres://hc3ng:***@pgsql.dsa.lan/dsa_student
# 117 rows affected.
# [('HOMICIDE', 'FIRST DEGREE MURDER', 'I', '110'),
#  ('HOMICIDE', 'SECOND DEGREE MURDER', 'I', '130'),
#  ('HOMICIDE', 'INVOLUNTARY MANSLAUGHTER', 'N', '141'),
#  ('HOMICIDE', 'RECKLESS HOMICIDE', 'N', '142'),
#  ('WEAPONS VIOLATION', 'SALE OF METAL PIERCING BULLETS', 'N', '1475'),
#  ('GAMBLING', 'BOLITA OR BOLI PUL/STATION', 'N', '1623'),
#  ('GAMBLING', 'WIREROOM/NUMBERS', 'N', '1632'),
#  ('GAMBLING', 'POLICY/HOUSEBOOK', 'N', '1690'),
#  ('GAMBLING', 'POLICY/STATION', 'N', '1691'),
#  ('GAMBLING', 'POLICY/RUNNER', 'N', '1692'),
#  ('GAMBLING', 'POLICY/TURN-IN', 'N', '1693'),
#  ('GAMBLING', 'POLICY/OFFICE', 'N', '1694'),
#  ('GAMBLING', 'POLICY/PRESS', 'N', '1695'),
#  ('GAMBLING', 'POLICY/WHEEL', 'N', '1696'),
#  ('OFFENSE INVOLVING CHILDREN', 'SALE OF TRAVEL TICKET TO MINOR', 'N', '1775'),
#  ('CRIMINAL ABORTION', 'CRIMINAL ABORTION', 'N', '2500'),
#  ('CRIM SEXUAL ASSAULT', 'AGGRAVATED: HANDGUN', 'I', '261'),
#  ('CRIM SEXUAL ASSAULT', 'AGGRAVATED: OTHER FIREARM', 'I', '262'),
#  ('CRIM SEXUAL ASSAULT', 'AGGRAVATED: KNIFE/CUT INSTR', 'I', '263'),
#  ('CRIM SEXUAL ASSAULT', 'AGGRAVATED: OTHER DANG WEAPON', 'I', '264'),
#  ('CRIM SEXUAL ASSAULT', 'AGGRAVATED: OTHER', 'I', '265'),
#  ('CRIM SEXUAL ASSAULT', 'PREDATORY', 'I', '266'),
#  ('CRIM SEXUAL ASSAULT', 'ATTEMPT AGG: HANDGUN', 'I', '271'),
#  ('CRIM SEXUAL ASSAULT', 'ATTEMPT AGG: OTHER FIREARM', 'I', '272'),
#  ('CRIM SEXUAL ASSAULT', 'ATTEMPT AGG: KNIFE/CUT INSTR', 'I', '273'),
#  ('CRIM SEXUAL ASSAULT', 'ATTEMPT AGG: OTHER DANG WEAPON', 'I', '274'),
#  ('CRIM SEXUAL ASSAULT', 'ATTEMPT AGG: OTHER', 'I', '275'),
#  ('CRIM SEXUAL ASSAULT', 'NON-AGGRAVATED', 'I', '281'),
#  ('CRIM SEXUAL ASSAULT', 'ATTEMPT NON-AGGRAVATED', 'I', '291'),
#  ('ROBBERY', 'ARMED:KNIFE/CUTTING INSTRUMENT', 'I', '312'),
#  ('ROBBERY', 'ARMED: OTHER DANGEROUS WEAPON', 'I', '313'),
#  ('ROBBERY', 'STRONGARM - NO WEAPON', 'I', '320'),
#  ('ROBBERY', 'VEHICULAR HIJACKING', 'I', '325'),
#  ('ROBBERY', 'AGGRAVATED VEHICULAR HIJACKING', 'I', '326'),
#  ('ROBBERY', 'AGGRAVATED', 'I', '330'),
#  ('ROBBERY', 'ATTEMPT: AGGRAVATED', 'I', '331'),
#  ('ROBBERY', 'ATTEMPT: ARMED-KNIFE/CUT INSTR', 'I', '334'),
#  ('ROBBERY', 'ATTEMPT: ARMED-OTHER DANG WEAP', 'I', '337'),
#  ('ROBBERY', 'ATTEMPT: STRONGARM-NO WEAPON', 'I', '340'),
#  ('BATTERY', 'AGGRAVATED:KNIFE/CUTTING INSTR', 'I', '420'),
#  ('BATTERY', 'AGGRAVATED: OTHER DANG WEAPON', 'I', '430'),
#  ('BATTERY', 'AGG: HANDS/FIST/FEET NO/MINOR INJURY', 'N', '440'),
#  ('OTHER OFFENSE', 'DESTRUCTION OF DRAFT CARD', 'N', '4410'),
#  ('OTHER OFFENSE', 'CRIMINAL FORTIFICATION', 'N', '4420'),
#  ('BATTERY', 'AGGRAVATED PO: HANDGUN', 'I', '450'),
#  ('BATTERY', 'AGGRAVATED PO: OTHER FIREARM', 'I', '451'),
#  ('BATTERY', 'AGGRAVATED PO: KNIFE/CUT INSTR', 'I', '452'),
#  ('BATTERY', 'AGGRAVATED PO: OTHER DANG WEAP', 'I', '453'),
#  ('BATTERY', 'AGG PO HANDS NO/MIN INJURY', 'N', '454'),
#  ('BATTERY', 'SIMPLE', 'N', '460'),
#  ('BATTERY', 'AGG PO HANDS ETC SERIOUS INJ', 'I', '461'),
#  ('BATTERY', 'AGG PRO EMP HANDS SERIOUS INJ', 'I', '462'),
#  ('PUBLIC PEACE VIOLATION', 'RECKLESS CONDUCT', 'N', '470'),
#  ('BATTERY', 'OF UNBORN CHILD', 'N', '475'),
#  ('BATTERY', 'AGG: HANDS/FIST/FEET SERIOUS INJURY', 'I', '479'),
#  ('BATTERY', 'AGG PRO.EMP: HANDGUN', 'I', '480'),
#  ('BATTERY', 'AGG PRO.EMP: OTHER FIREARM', 'I', '481'),
#  ('BATTERY', 'AGG PRO.EMP:KNIFE/CUTTING INST', 'I', '482'),
#  ('BATTERY', 'AGG PRO.EMP: OTHER DANG WEAPON', 'I', '483'),
#  ('BATTERY', 'PRO EMP HANDS NO/MIN INJURY', 'N', '484'),
#  ('BATTERY', 'AGGRAVATED OF A CHILD', 'I', '485'),
#  ('BATTERY', 'DOMESTIC BATTERY SIMPLE', 'N', '486'),
#  ('BATTERY', 'AGGRAVATED OF A UNBORN CHILD', 'I', '487'),
#  ('BATTERY', 'AGGRAVATED DOMESTIC BATTERY: HANDGUN', 'I', '488'),
#  ('BATTERY', 'AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM', 'I', '489'),
#  ('RITUALISM', 'AGG RITUAL MUT:HANDGUN', 'I', '490'),
#  ('RITUALISM', 'AGG RITUAL MUT:OTHER FIREARM', 'I', '491'),
#  ('RITUALISM', 'AGG RITUAL MUT:KNIFE/CUTTING I', 'I', '492'),
#  ('RITUALISM', 'AGG RITUAL MUT:OTH DANG WEAPON', 'I', '493'),
#  ('RITUALISM', 'AGG RIT MUT: HANDS/FIST/FEET NO/MINOR INJURY', 'N', '494'),
#  ('BATTERY', 'AGGRAVATED OF A SENIOR CITIZEN', 'I', '495'),
#  ('BATTERY', 'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST', 'I', '496'),
#  ('BATTERY', 'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON', 'I', '497'),
#  ('BATTERY', 'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY', 'I', '498'),
#  ('RITUALISM', 'AGG RIT MUT: HANDS/FIST/FEET SERIOUS INJURY', 'I', '510'),
#  ('ASSAULT', 'AGGRAVATED:KNIFE/CUTTING INSTR', 'I', '520'),
#  ('ASSAULT', 'AGGRAVATED: OTHER DANG WEAPON', 'I', '530'),
#  ('ASSAULT', 'PRO EMP HANDS NO/MIN INJURY', 'N', '545'),
#  ('ASSAULT', 'AGGRAVATED PO: HANDGUN', 'I', '550'),
#  ('ASSAULT', 'AGGRAVATED PO: OTHER FIREARM', 'I', '551'),
#  ('ASSAULT', 'AGGRAVATED PO:KNIFE/CUT INSTR', 'I', '552'),
#  ('ASSAULT', 'AGGRAVATED PO: OTHER DANG WEAP', 'I', '553'),
#  ('ASSAULT', 'AGG PO HANDS NO/MIN INJURY', 'N', '554'),
#  ('ASSAULT', 'AGG PRO.EMP: HANDGUN', 'I', '555'),
#  ('ASSAULT', 'AGG PRO.EMP: OTHER FIREARM', 'I', '556'),
#  ('ASSAULT', 'AGG PRO.EMP:KNIFE/CUTTING INST', 'I', '557'),
#  ('ASSAULT', 'AGG PRO.EMP: OTHER DANG WEAPON', 'I', '558'),
#  ('ASSAULT', 'SIMPLE', 'N', '560'),
#  ('STALKING', 'SIMPLE', 'N', '580'),
#  ('STALKING', 'AGGRAVATED', 'N', '581'),
#  ('STALKING', 'CYBERSTALKING', 'N', '583'),
#  ('STALKING', 'VIOLATION OF STALKING NO CONTACT ORDER', 'N', '584'),
#  ('BURGLARY', 'FORCIBLE ENTRY', 'I', '610'),
#  ('BURGLARY', 'UNLAWFUL ENTRY', 'I', '620'),
#  ('BURGLARY', 'ATTEMPT FORCIBLE ENTRY', 'I', '630'),
#  ('BURGLARY', 'HOME INVASION', 'I', '650'),
#  ('THEFT', 'OVER $500', 'I', '810'),
#  ('THEFT', '$500 AND UNDER', 'I', '820'),
#  ('THEFT', 'ATTEMPT THEFT', 'I', '850'),
#  ('THEFT', 'RETAIL THEFT', 'I', '860'),
#  ('THEFT', 'DELIVERY CONTAINER THEFT', 'I', '865'),
#  ('THEFT', 'POCKET-PICKING', 'I', '870'),
#  ('THEFT', 'PURSE-SNATCHING', 'I', '880'),
#  ('THEFT', 'FROM BUILDING', 'I', '890'),
#  ('THEFT', 'FROM COIN-OP MACHINE/DEVICE', 'I', '895'),
#  ('MOTOR VEHICLE THEFT', 'AUTOMOBILE', 'I', '910'),
#  ('MOTOR VEHICLE THEFT', 'TRUCK, BUS, MOTOR HOME', 'I', '915'),
#  ('MOTOR VEHICLE THEFT', 'CYCLE, SCOOTER, BIKE W-VIN', 'I', '917'),
#  ('MOTOR VEHICLE THEFT', 'CYCLE, SCOOTER, BIKE NO VIN', 'I', '918'),
#  ('MOTOR VEHICLE THEFT', 'ATT: AUTOMOBILE', 'I', '920'),
#  ('MOTOR VEHICLE THEFT', 'ATT: TRUCK, BUS, MOTOR HOME', 'I', '925'),
#  ('MOTOR VEHICLE THEFT', 'ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN', 'I', '927'),
#  ('MOTOR VEHICLE THEFT', 'ATTEMPT: CYCLE, SCOOTER, BIKE NO VIN', 'I', '928'),
#  ('MOTOR VEHICLE THEFT', 'THEFT/RECOVERY: AUTOMOBILE', 'I', '930'),
#  ('MOTOR VEHICLE THEFT', 'THEFT/RECOVERY: TRUCK,BUS,MHOME', 'I', '935'),
#  ('MOTOR VEHICLE THEFT', 'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN', 'I', '937'),
#  ('MOTOR VEHICLE THEFT', 'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE NO VIN', 'I', '938')]

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# ### 5- For each year, which month is ranked #1 as having the greatest number of crime incidents with a primary crime description containing the term "NARCOTICS" or secondary crime desciption containing the phrase "GUN"? Display the year, month of the cases incident date, the primary and secondary crime description, the count of incidents and the ranking number. Order by year descending.
#
# <span style="font-size:7px"><b>Hint:</b>22 rows affected -- data[2012-2, incidents=1942] ranking# should all be 1 -- involves parsing dates, a nested query with a window function and groups</span>

# %%
# %%sql
#
# SELECT * FROM (
#     SELECT rank () OVER (PARTITION BY year ORDER BY Counts_of_Crimes DESC), year, month, Counts_of_Crimes,
#     iucr_primary_desc, iucr_secondary_desc
#     FROM (
#     SELECT CAST (EXTRACT (YEAR FROM incident_date) AS INT) AS YEAR, Date_part ('month', incident_date) AS month,
#     iucr_primary_desc, iucr_secondary_desc, COUNT (case_number) AS Counts_of_Crimes
#     FROM cc_cases
#     JOIN cc_iucr_codes_primary_descriptions USING (iucr_code)
#     JOIN cc_iucr_codes_secondary_descriptions USING (iucr_code)
#     WHERE iucr_primary_desc LIKE '%NARCOTICS%'
#     OR iucr_secondary_desc LIKE '%GUN%'
#     GROUP BY month, year, iucr_primary_desc, iucr_secondary_desc
#     ORDER BY year DESC)
# QUERY1) QUERY2 WHERE rank = 1;
# Out:
#  * postgres://hc3ng:***@pgsql.dsa.lan/dsa_student
# 22 rows affected.
# [(1, 2001, 1.0, 1460, 'NARCOTICS', 'POSS: CRACK'),
#  (1, 2002, 2.0, 1523, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2003, 5.0, 1644, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2004, 2.0, 1741, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2005, 3.0, 1818, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2006, 5.0, 1824, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2007, 7.0, 2121, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2008, 8.0, 2083, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2009, 3.0, 1993, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2010, 3.0, 2296, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2011, 3.0, 1919, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2012, 2.0, 1942, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2013, 3.0, 1590, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2014, 7.0, 1253, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2015, 3.0, 1115, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2016, 3.0, 559, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS'),
#  (1, 2017, 1.0, 458, 'ROBBERY', 'ARMED: HANDGUN'),
#  (1, 2018, 7.0, 375, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OF HANDGUN'),
#  (1, 2019, 7.0, 455, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OF HANDGUN'),
#  (1, 2020, 8.0, 623, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OF HANDGUN'),
#  (1, 2021, 6.0, 617, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OF HANDGUN'),
#  (1, 2022, 5.0, 647, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OF HANDGUN')]

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# ### 6 What is the average difference (in days, expressed as an integer) between the updated and incident dates for case arrests and primary and secondary crime descriptions ordered by the average difference in days.
#
# <span style="font-size:7px"><b>Hint:</b>HINT: 538 rows affected -- output first row data[NARCOTICS,SALE/DEL DRUG PARAPHERNALIA,False,6] -- Involves Aggregate groups, parse date, calculate date difference</span>

# %%
# %%sql
# SELECT arrest, iucr_primary_desc, iucr_secondary_desc, CAST (AVG(Date_Part('day', updated_on::timestamp - incident_date::timestamp)) AS INT) AS Average_Duration
# FROM cc_cases
# JOIN cc_iucr_codes_primary_descriptions USING (iucr_code)
# JOIN cc_iucr_codes_secondary_descriptions USING (iucr_code)
# GROUP BY arrest, iucr_primary_desc, Iucr_secondary_desc
# ORDER BY Average_Duration;
# Out:
#  * postgres://hc3ng:***@pgsql.dsa.lan/dsa_student
# 538 rows affected.
# [(0, 'NARCOTICS', 'SALE/DEL DRUG PARAPHERNALIA', 6),
#  (0, 'PROSTITUTION', 'PANDERING', 31),
#  (0, 'CONCEALED CARRY LICENSE VIOLATION', 'ARMED WHILE UNDER THE INFLUENCE', 45),
#  (0, 'OTHER OFFENSE', 'GUN OFFENDER: DUTY TO REPORT CHANGE OF INFORMATION', 52),
#  (0, 'NON-CRIMINAL', 'CONCEALED CARRY LICENSE REVOCATION', 59),
#  (1, 'CONCEALED CARRY LICENSE VIOLATION', 'PROHIBITED PLACES', 96),
#  (1, 'NON-CRIMINAL', 'CONCEALED CARRY LICENSE REVOCATION', 97),
#  (1, 'OTHER OFFENSE', 'GUN OFFENDER: DUTY TO REPORT CHANGE OF INFORMATION', 122),
#  (1, 'OTHER OFFENSE', 'ARSONIST: DUTY TO REGISTER', 129),
#  (0, 'CONCEALED CARRY LICENSE VIOLATION', 'PROHIBITED PLACES', 138),
#  (0, 'PUBLIC PEACE VIOLATION', 'LOOTING', 138),
#  (1, 'CONCEALED CARRY LICENSE VIOLATION', 'OTHER', 140),
#  (1, 'CONCEALED CARRY LICENSE VIOLATION', 'ARMED WHILE UNDER THE INFLUENCE', 141),
#  (1, 'DECEPTIVE PRACTICE', 'ALTER COINS', 151),
#  (0, 'OTHER OFFENSE', 'ARSONIST: ANNUAL REGISTRATION', 161),
#  (0, 'OTHER OFFENSE', 'VIOLENT OFFENDER: ANNUAL REGISTRATION', 172),
#  (1, 'OTHER OFFENSE', 'ARSONIST: FAIL TO REGISTER NEW ADDRESS', 177),
#  (0, 'OTHER OFFENSE', 'VIOLATION OF CIVIL NO CONTACT ORDER', 187),
#  (0, 'OTHER OFFENSE ', 'VIOLATION GPS MONITORING DEVICE ', 198),
#  (1, 'OTHER OFFENSE', 'VIOLENT OFFENDER: DUTY TO REGISTER', 200),
#  (1, 'OTHER OFFENSE', 'VIOLENT OFFENDER: FAIL TO REGISTER NEW ADDRESS', 203),
#  (0, 'OTHER OFFENSE', 'VIOLENT OFFENDER: FAIL TO REGISTER NEW ADDRESS', 208),
#  (0, 'OTHER OFFENSE', 'GUN OFFENDER: ANNUAL REGISTRATION', 212),
#  (0, 'OTHER OFFENSE', 'VIOLENT OFFENDER: DUTY TO REGISTER', 227),
#  (1, 'OTHER OFFENSE', 'VIOLATION OF CIVIL NO CONTACT ORDER', 234),
#  (1, 'OTHER OFFENSE', 'GUN OFFENDER: ANNUAL REGISTRATION', 248),
#  (0, 'WEAPONS VIOLATION', 'RECKLESS FIREARM DISCHARGE', 265),
#  (0, 'CONCEALED CARRY LICENSE VIOLATION', 'OTHER', 282),
#  (0, 'DECEPTIVE PRACTICE', 'FINANCIAL IDENTITY THEFT $300 AND UNDER', 291),
#  (1, 'OTHER OFFENSE ', 'VIOLATION GPS MONITORING DEVICE ', 293),
#  (1, 'OTHER OFFENSE', 'VIOLENT OFFENDER: ANNUAL REGISTRATION', 314),
#  (0, 'DECEPTIVE PRACTICE', 'ATTEMPT - FINANCIAL IDENTITY THEFT', 343),
#  (0, 'HUMAN TRAFFICKING', 'COMMERCIAL SEX ACTS', 351),
#  (1, 'DECEPTIVE PRACTICE', 'FINANCIAL IDENTITY THEFT $300 AND UNDER', 370),
#  (1, 'OTHER OFFENSE', 'ARSONIST: ANNUAL REGISTRATION', 374),
#  (0, 'HUMAN TRAFFICKING', 'INVOLUNTARY SERVITUDE', 435),
#  (1, 'DECEPTIVE PRACTICE', 'FINANCIAL IDENTITY THEFT OVER $ 300', 476),
#  (1, 'OTHER OFFENSE', 'GUN OFFENDER: DUTY TO REGISTER', 478),
#  (1, 'NARCOTICS', 'MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA', 513),
#  (0, 'DECEPTIVE PRACTICE', 'AGGRAVATED FINANCIAL IDENTITY THEFT', 513),
#  (0, 'OTHER OFFENSE', 'GUN OFFENDER: DUTY TO REGISTER', 516),
#  (1, 'DECEPTIVE PRACTICE', 'ATTEMPT - FINANCIAL IDENTITY THEFT', 519),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL USE OTHER FIREARM', 547),
#  (0, 'DECEPTIVE PRACTICE', 'FINANCIAL IDENTITY THEFT OVER $ 300', 608),
#  (1, 'HUMAN TRAFFICKING', 'COMMERCIAL SEX ACTS', 653),
#  (1, 'INTIMIDATION', 'COMPELLING CONFESSION', 653),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'OBSTRUCTING IDENTIFICATION', 742),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'CONTRABAND IN PRISON', 756),
#  (1, 'PUBLIC PEACE VIOLATION', 'LOOTING', 765),
#  (1, 'DECEPTIVE PRACTICE', 'AGGRAVATED FINANCIAL IDENTITY THEFT', 795),
#  (0, 'OBSCENITY', 'OBSCENE MATTER', 862),
#  (1, 'OTHER OFFENSE', 'PAROLE VIOLATION', 904),
#  (0, 'DECEPTIVE PRACTICE', 'UNAUTHORIZED VIDEOTAPING', 927),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'CHILD PORNOGRAPHY', 945),
#  (0, 'INTIMIDATION', 'EXTORTION', 958),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL USE HANDGUN', 961),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'OBSTRUCTING IDENTIFICATION', 977),
#  (0, 'OBSCENITY', 'OBSCENITY', 1028),
#  (0, 'PUBLIC PEACE VIOLATION', 'PUBLIC DEMONSTRATION', 1028),
#  (1, 'NARCOTICS', 'POSSESSION: SYNTHETIC MARIJUANA', 1092),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'SALE TOBACCO PRODUCTS TO MINOR', 1149),
#  (0, 'OTHER OFFENSE', 'DISCLOSE DV VICTIM LOCATION', 1172),
#  (1, 'OBSCENITY', 'SALE/DIST OBSCENE MAT TO MINOR', 1179),
#  (0, 'OTHER OFFENSE', 'HARASSMENT BY ELECTRONIC MEANS', 1181),
#  (1, 'NARCOTICS', 'POSS: METHAMPHETAMINES', 1190),
#  (0, 'OTHER OFFENSE', 'ARSONIST: FAIL TO REGISTER NEW ADDRESS', 1198),
#  (0, 'SEX OFFENSE', 'OTHER', 1219),
#  (0, 'OBSCENITY', 'SALE/DIST OBSCENE MAT TO MINOR', 1228),
#  (0, 'DECEPTIVE PRACTICE', 'AGGRAVATED COMPUTER TAMPERING', 1257),
#  (1, 'NARCOTICS', 'POSS: BARBITUATES', 1302),
#  (0, 'PUBLIC PEACE VIOLATION', 'ARMED VIOLENCE', 1317),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'REFUSING TO AID AN OFFICER', 1334),
#  (0, 'PUBLIC PEACE VIOLATION', 'INTERFERE W/ EMERGENCY EQUIP', 1392),
#  (1, 'PUBLIC PEACE VIOLATION', 'PUBLIC DEMONSTRATION', 1399),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'POS: PORNOGRAPHIC PRINT', 1401),
#  (1, 'OTHER OFFENSE', 'HARASSMENT BY ELECTRONIC MEANS', 1438),
#  (1, 'NARCOTICS', 'POSS: SYNTHETIC DRUGS', 1439),
#  (0, 'OTHER OFFENSE', 'PAROLE VIOLATION', 1450),
#  (1, 'OTHER OFFENSE', 'ABUSE/NEGLECT: CARE FACILITY', 1493),
#  (1, 'OTHER OFFENSE', 'UNLAWFUL USE OF BODY ARMOR', 1497),
#  (0, 'NARCOTICS', 'MANU/DELIVER: METHAMPHETAMINES', 1550),
#  (0, 'NARCOTICS', 'CALCULATED CANNABIS CONSPIRACY', 1556),
#  (0, 'NARCOTICS', 'MANU/DELIVER:PCP', 1560),
#  (1, 'WEAPONS VIOLATION', 'RECKLESS FIREARM DISCHARGE', 1560),
#  (1, 'NARCOTICS', 'MANU/DELIVER:SYNTHETIC DRUGS', 1566),
#  (0, 'NARCOTICS', 'MANU/DELIVER:HEROIN(BLACK TAR)', 1571),
#  (0, 'NARCOTICS', 'MANU/DELIVER:BARBITUATES', 1585),
#  (1, 'OTHER OFFENSE', 'VIOLATION OF SMOKING BAN', 1592),
#  (0, 'NARCOTICS', 'POSS: BARBITUATES', 1628),
#  (1, 'OBSCENITY', 'OBSCENE MATTER', 1638),
#  (1, 'NARCOTICS', 'MANU/DELIVER: METHAMPHETAMINES', 1702),
#  (1, 'HUMAN TRAFFICKING', 'INVOLUNTARY SERVITUDE', 1722),
#  (1, 'OTHER OFFENSE', 'BOARD PLANE WITH WEAPON', 1732),
#  (0, 'NARCOTICS', 'POSSESSION: SYNTHETIC MARIJUANA', 1733),
#  (0, 'CRIMINAL TRESPASS', 'TO VEHICLE', 1742),
#  (0, 'PUBLIC PEACE VIOLATION', 'OTHER VIOLATION', 1742),
#  (0, 'OTHER OFFENSE', 'LICENSE VIOLATION', 1778),
#  (0, 'OTHER OFFENSE', 'VEHICLE TITLE/REG OFFENSE', 1778),
#  (0, 'NARCOTICS', 'DELIVER CANNABIS TO PERSON <18', 1782),
#  (0, 'PUBLIC INDECENCY', 'LICENSED PREMISE', 1788),
#  (0, 'SEX OFFENSE', 'SEXUAL EXPLOITATION OF A CHILD', 1788),
#  (0, 'DECEPTIVE PRACTICE', 'DECEPTIVE COLLECTION PRACTICES', 1789),
#  (1, 'NARCOTICS', 'MANU/DELIVER:PCP', 1801),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'OBSTRUCTING SERVICE', 1832),
#  (0, 'DECEPTIVE PRACTICE', 'COMPUTER FRAUD', 1868),
#  (0, 'OTHER OFFENSE', 'ABUSE/NEGLECT: CARE FACILITY', 1898),
#  (0, 'NARCOTICS', 'MANU/DELIVER:SYNTHETIC DRUGS', 1913),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'CONTRIBUTE CRIM DELINQUENCY JUVENILE', 1916),
#  (0, 'NARCOTICS', 'POSS: METHAMPHETAMINES', 1924),
#  (0, 'OTHER OFFENSE', 'EAVESDROPPING', 1935),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'CONTRIBUTE CRIM DELINQUENCY JUVENILE', 1943),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OF HANDGUN', 1947),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL POSS AMMUNITION', 1965),
#  (1, 'NARCOTICS', 'CONT SUBS:FAIL TO MAINT RECORD', 1973),
#  (0, 'NARCOTICS', 'FOUND SUSPECT NARCOTICS', 1996),
#  (1, 'NARCOTICS', 'MANU/DELIVER:BARBITUATES', 2008),
#  (0, 'OTHER NARCOTIC VIOLATION', 'INTOXICATING COMPOUNDS', 2020),
#  (1, 'SEX OFFENSE', 'SEX RELATION IN FAMILY', 2030),
#  (1, 'WEAPONS VIOLATION', 'DEFACE IDENT MARKS OF FIREARM', 2031),
#  (0, 'OTHER OFFENSE', 'TAMPER WITH MOTOR VEHICLE', 2031),
#  (1, 'PUBLIC INDECENCY', 'LICENSED PREMISE', 2052),
#  (0, 'NARCOTICS', 'CANNABIS PLANT', 2071),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL POSS AMMUNITION', 2092),
#  (0, 'DECEPTIVE PRACTICE', 'THEFT OF LOST/MISLAID PROP', 2100),
#  (1, 'DECEPTIVE PRACTICE', 'UNAUTHORIZED VIDEOTAPING', 2108),
#  (1, 'OBSCENITY', 'OBSCENITY', 2130),
#  (0, 'OTHER OFFENSE', 'OTHER ARSON/EXPLOSIVE INCIDENT', 2130),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'AGG CRIM SEX ABUSE FAM MEMBER', 2134),
#  (0, 'ASSAULT', 'AGGRAVATED: HANDGUN', 2135),
#  (1, 'DECEPTIVE PRACTICE', 'ILLEGAL POSSESSION CASH CARD', 2136),
#  (0, 'SEX OFFENSE', 'INDECENT SOLICITATION/ADULT', 2136),
#  (1, 'PUBLIC PEACE VIOLATION', 'OTHER VIOLATION', 2137),
#  (0, 'OTHER OFFENSE', 'VIOLATION OF SMOKING BAN', 2137),
#  (0, 'WEAPONS VIOLATION', 'DEFACE IDENT MARKS OF FIREARM', 2141),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'OBSTRUCTING SERVICE', 2142),
#  (0, 'SEX OFFENSE', 'SEX RELATION IN FAMILY', 2160),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'POS: PORNOGRAPHIC PRINT', 2161),
#  (0, 'DECEPTIVE PRACTICE', 'CREDIT CARD FRAUD', 2162),
#  (1, 'OTHER OFFENSE', 'VEHICLE TITLE/REG OFFENSE', 2174),
#  (0, 'DECEPTIVE PRACTICE', 'ALTER COINS', 2181),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'RESIST/OBSTRUCT/DISARM OFFICER', 2195),
#  (0, 'ARSON', 'POS: EXPLOSIVE/INCENDIARY DEV', 2196),
#  (0, 'NARCOTICS', 'MANU/DEL:CANNABIS 10GM OR LESS', 2198),
#  (0, 'OTHER OFFENSE', 'OTHER CRIME AGAINST PERSON', 2204),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OF HANDGUN', 2210),
#  (0, 'DECEPTIVE PRACTICE', 'COUNTERFEIT CHECK', 2221),
#  (0, 'PROSTITUTION', 'PIMPING', 2226),
#  (0, 'NARCOTICS', 'POSS: CANNABIS MORE THAN 30GMS', 2227),
#  (0, 'NARCOTICS', 'MANU/DELIVER: HEROIN (WHITE)', 2228),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'OTHER OFFENSE', 2229),
#  (1, 'OTHER OFFENSE', 'LICENSE VIOLATION', 2241),
#  (0, 'ASSAULT', 'AGGRAVATED: OTHER FIREARM', 2247),
#  (0, 'DECEPTIVE PRACTICE', 'INSURANCE FRAUD', 2252),
#  (0, 'NARCOTICS', 'CRIMINAL DRUG CONSPIRACY', 2260),
#  (0, 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR', 2270),
#  (0, 'DECEPTIVE PRACTICE', 'FRAUD OR CONFIDENCE GAME', 2277),
#  (0, 'CRIMINAL TRESPASS', 'TO RESIDENCE', 2278),
#  (0, 'OTHER OFFENSE', 'INTERFERE W/ HIGHER EDUCATION', 2297),
#  (0, 'LIQUOR LAW VIOLATION', 'LIQUOR LICENSE VIOLATION', 2320),
#  (0, 'DECEPTIVE PRACTICE', 'THEFT BY LESSEE,MOTOR VEH', 2324),
#  (0, 'GAMBLING', 'GAME/AMUSEMENT DEVICE', 2327),
#  (0, 'NARCOTICS', 'MANU/DEL:CANNABIS OVER 10 GMS', 2337),
#  (0, 'NARCOTICS', 'ALTER/FORGE PRESCRIPTION', 2343),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL USE HANDGUN', 2352),
#  (1, 'NARCOTICS', 'POSS: AMPHETAMINES', 2356),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'RESIST/OBSTRUCT/DISARM OFFICER', 2363),
#  (0, 'NARCOTICS', 'FORFEIT PROPERTY', 2371),
#  (0, 'DECEPTIVE PRACTICE', 'ILLEGAL USE CASH CARD', 2371),
#  (1, 'OTHER OFFENSE', 'SEX OFFENDER: FAIL TO REGISTER', 2376),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'CRIM SEX ABUSE BY FAM MEMBER', 2377),
#  (0, 'NARCOTICS', 'POSS: PCP', 2383),
#  (0, 'GAMBLING', 'BOLITA OR BOLI PUL/RUNNER', 2385),
#  (0, 'NARCOTICS', 'POSS: SYNTHETIC DRUGS', 2392),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'CHILD ABUSE', 2393),
#  (1, 'GAMBLING', 'LOTTERY/PARI-MUTUEL', 2428),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL SALE OTHER FIREARM', 2438),
#  (0, 'DECEPTIVE PRACTICE', 'IMPERSONATION', 2440),
#  (0, 'BATTERY', 'AGGRAVATED: HANDGUN', 2462),
#  (1, 'NARCOTICS', 'POSS: PCP', 2462),
#  (1, 'NARCOTICS', 'CRIMINAL DRUG CONSPIRACY', 2464),
#  (1, 'SEX OFFENSE', 'OTHER', 2469),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'OBSTRUCTING JUSTICE', 2470),
#  (0, 'OTHER OFFENSE', 'VIOLATE ORDER OF PROTECTION', 2472),
#  (0, 'PROSTITUTION', 'CALL OPERATION', 2478),
#  (1, 'NARCOTICS', 'FOUND SUSPECT NARCOTICS', 2504),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'CHILD ABANDONMENT', 2505),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'ENDANGERING LIFE/HEALTH CHILD', 2506),
#  (0, 'OBSCENITY', 'SALE OF OBSCENE MATERIALS', 2517),
#  (0, 'INTIMIDATION', 'COMPELLING CONFESSION', 2524),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'SALE TOBACCO PRODUCTS TO MINOR', 2539),
#  (0, 'DECEPTIVE PRACTICE', 'COUNTERFEITING DOCUMENT', 2546),
#  (1, 'PROSTITUTION', 'SOLICIT FOR PROSTITUTE', 2549),
#  (1, 'PROSTITUTION', 'PATRONIZE JUVENILE PROSTITUTE', 2553),
#  (0, 'OTHER OFFENSE', 'MONEY LAUNDERING', 2562),
#  (1, 'PUBLIC PEACE VIOLATION', 'INTERFERE W/ EMERGENCY EQUIP', 2565),
#  (0, 'ARSON', 'BY EXPLOSIVE', 2568),
#  (1, 'NARCOTICS', 'POSS: HALLUCINOGENS', 2571),
#  (1, 'NARCOTICS', 'MANU/DELIVER: HALLUCINOGEN', 2573),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'OBSTRUCTING JUSTICE', 2575),
#  (1, 'NARCOTICS', 'MANU/DEL:CANNABIS OVER 10 GMS', 2576),
#  (0, 'PUBLIC PEACE VIOLATION', 'FALSE POLICE REPORT', 2593),
#  (1, 'NARCOTICS', 'MANU/DEL:CANNABIS 10GM OR LESS', 2604),
#  (1, 'DECEPTIVE PRACTICE', 'LIBRARY THEFT', 2605),
#  (0, 'OTHER OFFENSE', 'SEX OFFENDER: FAIL TO REGISTER', 2616),
#  (1, 'NARCOTICS', 'MANU/DELIVER: HEROIN (WHITE)', 2623),
#  (1, 'CRIMINAL DAMAGE', 'TO CITY OF CHICAGO PROPERTY', 2632),
#  (0, 'SEX OFFENSE', 'INDECENT SOLICITATION/CHILD', 2646),
#  (0, 'SEX OFFENSE', 'CRIMINAL SEXUAL ABUSE', 2646),
#  (0, 'SEX OFFENSE', 'CRIMINAL TRANSMISSION OF HIV', 2647),
#  (0, 'NARCOTICS', 'MANU/DELIVER: HALLUCINOGEN', 2650),
#  (1, 'OTHER OFFENSE', 'OTHER WEAPONS VIOLATION', 2652),
#  (1, 'PUBLIC PEACE VIOLATION', 'SELL/ADVERTISE FIREWORKS', 2654),
#  (0, 'OTHER OFFENSE', 'OTHER WEAPONS VIOLATION', 2656),
#  (0, 'DECEPTIVE PRACTICE', 'UNLAWFUL USE OF A COMPUTER', 2670),
#  (0, 'NARCOTICS', 'POSS: HALLUCINOGENS', 2672),
#  (0, 'NARCOTICS', 'POSS: AMPHETAMINES', 2675),
#  (0, 'PROSTITUTION', 'SOLICIT FOR PROSTITUTE', 2675),
#  (1, 'NARCOTICS', 'DELIVER CANNABIS TO PERSON <18', 2678),
#  (0, 'ROBBERY', 'ATTEMPT: ARMED-OTHER FIREARM', 2684),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'CHILD PORNOGRAPHY', 2685),
#  (1, 'NARCOTICS', 'POSS: CANNABIS MORE THAN 30GMS', 2707),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OTHER FIREARM', 2710),
#  (1, 'CRIMINAL DAMAGE', 'LIBRARY VANDALISM', 2710),
#  (0, 'CRIMINAL DAMAGE', 'TO CITY OF CHICAGO PROPERTY', 2714),
#  (0, 'SEX OFFENSE', 'ATT AGG CRIMINAL SEXUAL ABUSE', 2720),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'SEX ASSLT OF CHILD BY FAM MBR', 2730),
#  (0, 'OTHER OFFENSE', 'PROBATION VIOLATION', 2743),
#  (0, 'OTHER OFFENSE', 'ANIMAL ABUSE/NEGLECT', 2744),
#  (0, 'ARSON', 'BY FIRE', 2745),
#  (1, 'SEX OFFENSE', 'ATT AGG CRIMINAL SEXUAL ABUSE', 2745),
#  (1, 'NARCOTICS', 'MANU/DELIVER: HEROIN(BRN/TAN)', 2747),
#  (1, 'OTHER OFFENSE', 'PROBATION VIOLATION', 2749),
#  (1, 'NARCOTICS', 'SALE/DEL DRUG PARAPHERNALIA', 2769),
#  (1, 'OTHER OFFENSE', 'INTERFERE W/ HIGHER EDUCATION', 2770),
#  (0, 'NARCOTICS', 'POSS: COCAINE', 2777),
#  (1, 'CRIMINAL TRESPASS', 'TO RESIDENCE', 2781),
#  (1, 'WEAPONS VIOLATION', 'POSS FIREARM/AMMO:NO FOID CARD', 2782),
#  (0, 'ROBBERY', 'ARMED: OTHER FIREARM', 2787),
#  (0, 'DECEPTIVE PRACTICE', 'THEFT OF LABOR/SERVICES', 2796),
#  (0, 'ROBBERY', 'ATTEMPT: ARMED-HANDGUN', 2806),
#  (0, 'ROBBERY', 'ARMED: HANDGUN', 2806),
#  (0, 'PUBLIC PEACE VIOLATION', 'PEEPING TOM', 2817),
#  (0, 'DECEPTIVE PRACTICE', 'FINAN EXPLOIT-ELDERLY/DISABLED', 2823),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'AIDING ARRESTEE ESCAPE', 2824),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'AGG SEX ASSLT OF CHILD FAM MBR', 2825),
#  (1, 'OTHER NARCOTIC VIOLATION', 'INTOXICATING COMPOUNDS', 2827),
#  (0, 'CRIMINAL TRESPASS', 'TO LAND', 2828),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'AGG CRIM SEX ABUSE FAM MEMBER', 2840),
#  (0, 'CRIMINAL DAMAGE', 'CRIMINAL DEFACEMENT', 2846),
#  (0, 'NARCOTICS', 'POSS: HEROIN(BRN/TAN)', 2848),
#  (1, 'LIQUOR LAW VIOLATION', 'LIQUOR LICENSE VIOLATION', 2848),
#  (0, 'DECEPTIVE PRACTICE', 'STOLEN PROP: BUY/RECEIVE/POS.', 2849),
#  (1, 'NARCOTICS', 'POSS: HEROIN(BRN/TAN)', 2862),
#  (0, 'DECEPTIVE PRACTICE', 'PAY TV SERVICE OFFENSES', 2870),
#  (0, 'NARCOTICS', 'POSS: HEROIN(WHITE)', 2870),
#  (1, 'SEX OFFENSE', 'CRIMINAL TRANSMISSION OF HIV', 2883),
#  (1, 'ARSON', 'POS: EXPLOSIVE/INCENDIARY DEV', 2886),
#  (1, 'ASSAULT', 'AGGRAVATED: HANDGUN', 2887),
#  (1, 'NARCOTICS', 'CANNABIS PLANT', 2895),
#  (0, 'DECEPTIVE PRACTICE', 'ILLEGAL POSSESSION CASH CARD', 2896),
#  (0, 'OTHER OFFENSE', 'HAZARDOUS MATERIALS VIOLATION', 2908),
#  (0, 'CRIMINAL TRESPASS', 'TO AIRPORT', 2909),
#  (1, 'CRIMINAL DAMAGE', 'CRIMINAL DEFACEMENT', 2912),
#  (1, 'ROBBERY', 'ARMED: OTHER FIREARM', 2915),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL USE OTHER FIREARM', 2924),
#  (0, 'OTHER OFFENSE', 'FALSE/STOLEN/ALTERED TRP', 2925),
#  (0, 'DECEPTIVE PRACTICE', 'EMBEZZLEMENT', 2926),
#  (0, 'OTHER OFFENSE', 'OTHER VEHICLE OFFENSE', 2929),
#  (0, 'CRIMINAL DAMAGE', 'TO PROPERTY', 2933),
#  (1, 'NARCOTICS', 'CALCULATED CANNABIS CONSPIRACY', 2938),
#  (0, 'CRIMINAL DAMAGE', 'TO VEHICLE', 2965),
#  (1, 'INTIMIDATION', 'EXTORTION', 2981),
#  (0, 'DECEPTIVE PRACTICE', 'FORGERY', 2985),
#  (1, 'OTHER OFFENSE', 'SEX OFFENDER: PROHIBITED ZONE', 2991),
#  (1, 'OTHER OFFENSE', 'FALSE/STOLEN/ALTERED TRP', 2992),
#  (1, 'SEX OFFENSE', 'INDECENT SOLICITATION/ADULT', 2994),
#  (0, 'OTHER OFFENSE', 'VIO BAIL BOND: DOM VIOLENCE', 3006),
#  (0, 'NARCOTICS', 'FAIL REGISTER LIC:CONT SUBS', 3010),
#  (0, 'SEX OFFENSE', 'AGG CRIMINAL SEXUAL ABUSE', 3017),
#  (1, 'CRIMINAL TRESPASS', 'TO VEHICLE', 3021),
#  (1, 'OTHER OFFENSE', 'MONEY LAUNDERING', 3022),
#  (0, 'SEX OFFENSE', 'ATT CRIM SEXUAL ABUSE', 3027),
#  (1, 'DECEPTIVE PRACTICE', 'UNIDENTIFIABLE RECORDING SOUND', 3028),
#  (1, 'SEX OFFENSE', 'SEXUAL EXPLOITATION OF A CHILD', 3029),
#  (0, 'KIDNAPPING', 'FORCIBLE DETENTION', 3030),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'ENDANGERING LIFE/HEALTH CHILD', 3034),
#  (1, 'DECEPTIVE PRACTICE', 'COUNTERFEIT CHECK', 3041),
#  (1, 'OTHER OFFENSE', 'VIOLATE ORDER OF PROTECTION', 3042),
#  (0, 'OTHER OFFENSE', 'SEX OFFENDER: FAIL REG NEW ADD', 3042),
#  (1, 'ROBBERY', 'ARMED: HANDGUN', 3048),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL POSS OTHER FIREARM', 3065),
#  (1, 'DECEPTIVE PRACTICE', 'COUNTERFEITING DOCUMENT', 3071),
#  (0, 'DECEPTIVE PRACTICE', 'LIBRARY THEFT', 3085),
#  (1, 'OTHER OFFENSE', 'SEX OFFENDER: FAIL REG NEW ADD', 3087),
#  (1, 'PUBLIC PEACE VIOLATION', 'ARMED VIOLENCE', 3090),
#  (0, 'SEX OFFENSE', 'PUBLIC INDECENCY', 3095),
#  (1, 'OTHER OFFENSE', 'ANIMAL ABUSE/NEGLECT', 3106),
#  (0, 'NARCOTICS', 'MANU/DELIVER:COCAINE', 3117),
#  (0, 'NARCOTICS', 'MANU/DELIVER:CRACK', 3124),
#  (0, 'WEAPONS VIOLATION', 'USE OF METAL PIERCING BULLETS', 3125),
#  (0, 'KIDNAPPING', 'UNLAWFUL RESTRAINT', 3125),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'ESCAPE', 3132),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL SALE HANDGUN', 3136),
#  (1, 'ROBBERY', 'ATTEMPT: ARMED-HANDGUN', 3137),
#  (0, 'WEAPONS VIOLATION', 'POSS FIREARM/AMMO:NO FOID CARD', 3145),
#  (1, 'NARCOTICS', 'POSSESSION OF DRUG EQUIPMENT', 3150),
#  (0, 'ARSON', 'ATTEMPT ARSON', 3150),
#  (1, 'DECEPTIVE PRACTICE', 'DECEPTIVE COLLECTION PRACTICES', 3150),
#  (0, 'INTIMIDATION', 'EDUCATIONAL INTIMIDAITON', 3161),
#  (0, 'DECEPTIVE PRACTICE', 'UNLAWFUL USE OF RECORDED SOUND', 3169),
#  (1, 'ASSAULT', 'AGGRAVATED: OTHER FIREARM', 3175),
#  (0, 'OTHER OFFENSE', 'TELEPHONE THREAT', 3178),
#  (1, 'NARCOTICS', 'POSS: HEROIN(WHITE)', 3183),
#  (0, 'NARCOTICS', 'MANU/DELIVER: HEROIN(BRN/TAN)', 3188),
#  (1, 'NARCOTICS', 'FORFEIT PROPERTY', 3190),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'AIDING ARRESTEE ESCAPE', 3191),
#  (1, 'OTHER OFFENSE', 'HAZARDOUS MATERIALS VIOLATION', 3205),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'CHILD ABANDONMENT', 3206),
#  (1, 'OTHER OFFENSE', 'VIO BAIL BOND: DOM VIOLENCE', 3220),
#  (0, 'DECEPTIVE PRACTICE', 'BOGUS CHECK', 3222),
#  (1, 'CRIMINAL DAMAGE', 'TO PROPERTY', 3235),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'AGG SEX ASSLT OF CHILD FAM MBR', 3236),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'ESCAPE', 3237),
#  (1, 'NARCOTICS', 'MANU/DELIVER:COCAINE', 3244),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'CRIM SEX ABUSE BY FAM MEMBER', 3244),
#  (0, 'PUBLIC PEACE VIOLATION', 'MOB ACTION', 3246),
#  (1, 'NARCOTICS', 'POSS: LOOK-ALIKE DRUGS', 3247),
#  (1, 'PUBLIC PEACE VIOLATION', 'MOB ACTION', 3249),
#  (0, 'SEX OFFENSE', 'BIGAMY', 3267),
#  (1, 'PROSTITUTION', 'CALL OPERATION', 3268),
#  (1, 'PUBLIC PEACE VIOLATION', 'FALSE POLICE REPORT', 3279),
#  (1, 'DECEPTIVE PRACTICE', 'UNLAWFUL USE OF A COMPUTER', 3281),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'CHILD ABUSE', 3281),
#  (0, 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 3282),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'OTHER OFFENSE', 3288),
#  (1, 'NARCOTICS', 'MANU/DELIVER:AMPHETAMINES', 3289),
#  (1, 'CRIMINAL TRESPASS', 'TO LAND', 3299),
#  (1, 'OTHER OFFENSE', 'HARASSMENT BY TELEPHONE', 3304),
#  (0, 'CRIMINAL DAMAGE', 'LIBRARY VANDALISM', 3309),
#  (1, 'CRIMINAL TRESPASS', 'TO AIRPORT', 3324),
#  (1, 'NARCOTICS', 'POSS: COCAINE', 3325),
#  (0, 'OTHER OFFENSE', 'HARASSMENT BY TELEPHONE', 3333),
#  (1, 'ARSON', 'AGGRAVATED', 3336),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'CONTRIBUTE DELINQUENCY OF A CHILD', 3338),
#  (1, 'DECEPTIVE PRACTICE', 'CREDIT CARD FRAUD', 3340),
#  (0, 'CRIMINAL DAMAGE', 'INSTITUTIONAL VANDALISM', 3347),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL', 3348),
#  (1, 'DECEPTIVE PRACTICE', 'THEFT BY LESSEE,NON-VEH', 3349),
#  (0, 'NARCOTICS', 'POSSESSION OF DRUG EQUIPMENT', 3350),
#  (1, 'DECEPTIVE PRACTICE', 'THEFT OF LABOR/SERVICES', 3357),
#  (0, 'PROSTITUTION', 'OTHER PROSTITUTION OFFENSE', 3360),
#  (1, 'OTHER OFFENSE', 'EAVESDROPPING', 3361),
#  (1, 'PROSTITUTION', 'JUVENILE PIMPING', 3367),
#  (1, 'CRIMINAL DAMAGE', 'TO VEHICLE', 3368),
#  (0, 'ARSON', 'AGGRAVATED', 3369),
#  (0, 'INTIMIDATION', 'INTIMIDATION', 3370),
#  (1, 'NARCOTICS', 'DEL CONT SUBS TO PERSON <18', 3379),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'OFFICIAL MISCONDUCT', 3380),
#  (1, 'SEX OFFENSE', 'CRIMINAL SEXUAL ABUSE', 3383),
#  (0, 'GAMBLING', 'GAME/CARDS', 3390),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'SEX ASSLT OF CHILD BY FAM MBR', 3391),
#  (1, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS', 3392),
#  (1, 'NARCOTICS', 'ALTER/FORGE PRESCRIPTION', 3401),
#  (0, 'CRIMINAL TRESPASS', 'TO STATE SUP LAND', 3402),
#  (1, 'DECEPTIVE PRACTICE', 'THEFT OF LOST/MISLAID PROP', 3404),
#  (1, 'LIQUOR LAW VIOLATION', 'ILLEGAL POSSESSION BY MINOR', 3405),
#  (1, 'DECEPTIVE PRACTICE', 'UNLAWFUL USE OF RECORDED SOUND', 3409),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'OFFICIAL MISCONDUCT', 3409),
#  (0, 'NARCOTICS', 'POSS: HEROIN(BLACK TAR)', 3412),
#  (1, 'DECEPTIVE PRACTICE', 'INSURANCE FRAUD', 3418),
#  (1, 'ARSON', 'BY FIRE', 3419),
#  (0, 'LIQUOR LAW VIOLATION', 'ILLEGAL POSSESSION BY MINOR', 3425),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'CONCEALING/AIDING A FUGITIVE', 3428),
#  (1, 'SEX OFFENSE', 'AGG CRIMINAL SEXUAL ABUSE', 3429),
#  (1, 'DECEPTIVE PRACTICE', 'FINAN EXPLOIT-ELDERLY/DISABLED', 3431),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'CHILD ABDUCTION', 3431),
#  (1, 'GAMBLING', 'GAME/DICE', 3432),
#  (0, 'NARCOTICS', 'POSS: CANNABIS 30GMS OR LESS', 3437),
#  (1, 'NARCOTICS', 'FAIL REGISTER LIC:CONT SUBS', 3438),
#  (1, 'BATTERY', 'AGGRAVATED: HANDGUN', 3442),
#  (1, 'NARCOTICS', 'POSS: HEROIN(BLACK TAR)', 3446),
#  (0, 'KIDNAPPING', 'KIDNAPPING', 3446),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL USE OTHER DANG WEAPON', 3455),
#  (1, 'DECEPTIVE PRACTICE', 'ILLEGAL USE CASH CARD', 3456),
#  (1, 'OTHER OFFENSE', 'POSSESSION OF BURGLARY TOOLS', 3459),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL SALE HANDGUN', 3470),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'BRIBERY', 3475),
#  (0, 'GAMBLING', 'GAME/DICE', 3482),
#  (1, 'PROSTITUTION', 'OTHER PROSTITUTION OFFENSE', 3487),
#  (1, 'OTHER OFFENSE', 'TELEPHONE THREAT', 3492),
#  (1, 'DECEPTIVE PRACTICE', 'COMPUTER FRAUD', 3501),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'CHILD ABDUCTION', 3506),
#  (1, 'PUBLIC PEACE VIOLATION', 'PEEPING TOM', 3521),
#  (1, 'KIDNAPPING', 'UNLAWFUL RESTRAINT', 3525),
#  (1, 'KIDNAPPING', 'AGGRAVATED', 3531),
#  (0, 'NARCOTICS', 'POSS: CRACK', 3534),
#  (0, 'PROSTITUTION', 'SOLICIT FOR BUSINESS', 3545),
#  (0, 'OTHER OFFENSE', 'POSSESSION OF BURGLARY TOOLS', 3547),
#  (1, 'CRIMINAL DAMAGE', 'INSTITUTIONAL VANDALISM', 3548),
#  (1, 'DECEPTIVE PRACTICE', 'THEFT BY LESSEE,MOTOR VEH', 3559),
#  (1, 'KIDNAPPING', 'FORCIBLE DETENTION', 3570),
#  (0, 'PROSTITUTION', 'SOLICIT ON PUBLIC WAY', 3573),
#  (1, 'SEX OFFENSE', 'INDECENT SOLICITATION/CHILD', 3575),
#  (0, 'PUBLIC PEACE VIOLATION', 'SELL/ADVERTISE FIREWORKS', 3576),
#  (0, 'NARCOTICS', 'MANU/DELIVER:AMPHETAMINES', 3576),
#  (1, 'INTIMIDATION', 'INTIMIDATION', 3582),
#  (0, 'PUBLIC PEACE VIOLATION', 'ARSON THREAT', 3585),
#  (1, 'NARCOTICS', 'MANU/DELIVER:LOOK-ALIKE DRUG', 3587),
#  (1, 'ARSON', 'ATTEMPT ARSON', 3596),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL SALE OTHER FIREARM', 3598),
#  (0, 'OFFENSE INVOLVING CHILDREN', 'HARBOR RUNAWAY', 3600),
#  (1, 'LIQUOR LAW VIOLATION', 'EMPLOY MINOR', 3608),
#  (0, 'CRIMINAL DAMAGE', 'TO FIRE FIGHT.APP.EQUIP', 3609),
#  (0, 'OTHER OFFENSE', 'OTHER CRIME INVOLVING PROPERTY', 3611),
#  (1, 'ROBBERY', 'ATTEMPT: ARMED-OTHER FIREARM', 3613),
#  (1, 'PROSTITUTION', 'SOLICIT OFF PUBLIC WAY', 3614),
#  (0, 'CRIMINAL DAMAGE', 'TO STATE SUP PROP', 3617),
#  (0, 'KIDNAPPING', 'AGGRAVATED', 3618),
#  (0, 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR', 3622),
#  (0, 'PROSTITUTION', 'CAB OPERATION', 3633),
#  (1, 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 3636),
#  (0, 'DECEPTIVE PRACTICE', 'UNIDENTIFIABLE RECORDING SOUND', 3645),
#  (1, 'PUBLIC PEACE VIOLATION', 'FALSE FIRE ALARM', 3655),
#  (0, 'PUBLIC PEACE VIOLATION', 'FALSE FIRE ALARM', 3674),
#  (1, 'INTIMIDATION', 'EDUCATIONAL INTIMIDAITON', 3683),
#  (0, 'GAMBLING', 'OTHER', 3688),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL USE/SALE AIR RIFLE', 3697),
#  (1, 'SEX OFFENSE', 'PUBLIC INDECENCY', 3702),
#  (1, 'OTHER OFFENSE', 'TAMPER WITH MOTOR VEHICLE', 3709),
#  (0, 'OTHER OFFENSE', 'COMPOUNDING A CRIME', 3712),
#  (0, 'DECEPTIVE PRACTICE', 'THEFT BY LESSEE,NON-VEH', 3719),
#  (0, 'OTHER OFFENSE', 'SEX OFFENDER: PROHIBITED ZONE', 3728),
#  (1, 'CRIMINAL DAMAGE', 'TO STATE SUP PROP', 3729),
#  (1, 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR', 3731),
#  (1, 'OTHER OFFENSE', 'OTHER ARSON/EXPLOSIVE INCIDENT', 3732),
#  (1, 'KIDNAPPING', 'KIDNAPPING', 3739),
#  (0, 'PROSTITUTION', 'SOLICIT OFF PUBLIC WAY', 3741),
#  (1, 'OTHER OFFENSE', 'OTHER CRIME AGAINST PERSON', 3746),
#  (0, 'NARCOTICS', 'POSS: LOOK-ALIKE DRUGS', 3748),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'HARBOR RUNAWAY', 3749),
#  (1, 'NARCOTICS', 'MANU/DELIVER:CRACK', 3758),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL USE/SALE AIR RIFLE', 3770),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'INTERFERENCE JUDICIAL PROCESS', 3797),
#  (0, 'NARCOTICS', 'SOLICIT NARCOTICS ON PUBLICWAY', 3809),
#  (1, 'ARSON', 'BY EXPLOSIVE', 3820),
#  (0, 'PUBLIC PEACE VIOLATION', 'BOMB THREAT', 3827),
#  (1, 'NARCOTICS', 'SOLICIT NARCOTICS ON PUBLICWAY', 3843),
#  (1, 'OFFENSE INVOLVING CHILDREN', 'CONTRIBUTE DELINQUENCY OF A CHILD', 3865),
#  (0, 'GAMBLING', 'ILLEGAL ILL LOTTERY', 3874),
#  (0, 'NARCOTICS', 'ATTEMPT POSSESSION NARCOTICS', 3881),
#  (1, 'DECEPTIVE PRACTICE', 'AGGRAVATED COMPUTER TAMPERING', 3882),
#  (0, 'NARCOTICS', 'DEL CONT SUBS TO PERSON <18', 3892),
#  (1, 'SEX OFFENSE', 'FORNICATION', 3893),
#  (1, 'DECEPTIVE PRACTICE', 'FORGERY', 3893),
#  (1, 'PROSTITUTION', 'SOLICIT ON PUBLIC WAY', 3907),
#  (0, 'KIDNAPPING', 'UNLAWFUL INTERFERE/VISITATION', 3910),
#  (0, 'ARSON', 'POS: CHEMICAL/DRY-ICE DEVICE', 3914),
#  (1, 'DECEPTIVE PRACTICE', 'STOLEN PROP: BUY/RECEIVE/POS.', 3923),
#  (1, 'CRIMINAL DAMAGE', 'TO FIRE FIGHT.APP.EQUIP', 3924),
#  (1, 'SEX OFFENSE', 'ATT CRIM SEXUAL ABUSE', 3926),
#  (1, 'PROSTITUTION', 'KEEP PLACE OF PROSTITUTION', 3931),
#  (1, 'INTIMIDATION', 'COMPELLING ORG MEMBERSHIP', 3933),
#  (1, 'CRIMINAL TRESPASS', 'TO STATE SUP LAND', 3945),
#  (0, 'INTIMIDATION', 'COMPELLING ORG MEMBERSHIP', 3961),
#  (1, 'DECEPTIVE PRACTICE', 'EMBEZZLEMENT', 3968),
#  (1, 'DECEPTIVE PRACTICE', 'IMPERSONATION', 3981),
#  (0, 'NARCOTICS', 'POS: HYPODERMIC NEEDLE', 3987),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'BRIBERY', 3988),
#  (1, 'PROSTITUTION', 'PIMPING', 3990),
#  (1, 'NARCOTICS', 'POSS: CRACK', 4006),
#  (0, 'NARCOTICS', 'ATTEMPT POSSESSION CANNABIS', 4006),
#  (1, 'PROSTITUTION', 'PANDERING', 4008),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'INTERFERENCE JUDICIAL PROCESS', 4012),
#  (0, 'OTHER OFFENSE', 'BOARD PLANE WITH WEAPON', 4014),
#  (1, 'DECEPTIVE PRACTICE', 'FRAUD OR CONFIDENCE GAME', 4016),
#  (1, 'WEAPONS VIOLATION', 'UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL', 4025),
#  (1, 'GAMBLING', 'OTHER', 4059),
#  (1, 'OTHER OFFENSE', 'COMPOUNDING A CRIME', 4067),
#  (1, 'PUBLIC PEACE VIOLATION', 'BOMB THREAT', 4070),
#  (1, 'OTHER OFFENSE', 'OBSCENE TELEPHONE CALLS', 4073),
#  (1, 'LIQUOR LAW VIOLATION', 'MINOR MISREPRESENT AGE', 4078),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'CONTRABAND IN PRISON', 4081),
#  (1, 'PUBLIC PEACE VIOLATION', 'ARSON THREAT', 4087),
#  (0, 'WEAPONS VIOLATION', 'UNLAWFUL USE OTHER DANG WEAPON', 4090),
#  (1, 'ARSON', 'POS: CHEMICAL/DRY-ICE DEVICE', 4109),
#  (1, 'OTHER OFFENSE', 'OTHER CRIME INVOLVING PROPERTY', 4117),
#  (1, 'OTHER OFFENSE', 'OTHER VEHICLE OFFENSE', 4127),
#  (1, 'NARCOTICS', 'MANU/DELIVER:HEROIN(BLACK TAR)', 4182),
#  (1, 'GAMBLING', 'REGISTER FED GAMBLING STAMP', 4188),
#  (0, 'PROSTITUTION', 'PATRONIZING A PROSTITUTE', 4202),
#  (1, 'GAMBLING', 'GAME/CARDS', 4223),
#  (1, 'PROSTITUTION', 'SOLICIT FOR BUSINESS', 4223),
#  (1, 'DECEPTIVE PRACTICE', 'BOGUS CHECK', 4254),
#  (1, 'NARCOTICS', 'POS: HYPODERMIC NEEDLE', 4260),
#  (0, 'OTHER OFFENSE', 'OBSCENE TELEPHONE CALLS', 4261),
#  (0, 'PROSTITUTION', 'IN TAVERN', 4284),
#  (1, 'PROSTITUTION', 'KEEP PLACE OF JUV PROSTITUTION', 4329),
#  (1, 'NARCOTICS', 'FAILURE TO KEEP HYPO RECORDS', 4340),
#  (1, 'INTERFERENCE WITH PUBLIC OFFICER', 'REFUSING TO AID AN OFFICER', 4348),
#  (0, 'SEX OFFENSE', 'FORNICATION', 4350),
#  (1, 'PROSTITUTION', 'IN TAVERN', 4385),
#  (0, 'BATTERY', 'AGGRAVATED: OTHER FIREARM', 4397),
#  (1, 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR', 4406),
#  (1, 'GAMBLING', 'LOTTERY/PARLAY CARDS', 4410),
#  (1, 'GAMBLING', 'BOOKMAKING/SPORTS', 4460),
#  (1, 'PROSTITUTION', 'CAB OPERATION', 4461),
#  (0, 'OTHER OFFENSE', 'ANIMAL FIGHTING', 4474),
#  (1, 'GAMBLING', 'BOLITA OR BOLI PUL/OFFICE', 4509),
#  (1, 'GAMBLING', 'GAME/AMUSEMENT DEVICE', 4525),
#  (1, 'WEAPONS VIOLATION', 'REGISTER OF SALES BY DEALER', 4533),
#  (0, 'SEX OFFENSE', 'MARRYING A BIGAMIST', 4568),
#  (1, 'OTHER OFFENSE', 'ANIMAL FIGHTING', 4579),
#  (1, 'PROSTITUTION', 'PATRONIZING A PROSTITUTE', 4594),
#  (0, 'DECEPTIVE PRACTICE', 'POSS. KEYS OR DEV.TO COIN MACH', 4595),
#  (1, 'NARCOTICS', 'ATTEMPT POSSESSION CANNABIS', 4637),
#  (0, 'INTERFERENCE WITH PUBLIC OFFICER', 'CONCEALING/AIDING A FUGITIVE', 4639),
#  (1, 'NARCOTICS', 'ATTEMPT POSSESSION NARCOTICS', 4696),
#  (1, 'DECEPTIVE PRACTICE', 'POSS. KEYS OR DEV.TO COIN MACH', 4712),
#  (1, 'GAMBLING', 'VIOL CHARITABLE GAME ACT', 4761),
#  (1, 'GAMBLING', 'ILLEGAL ILL LOTTERY', 4824),
#  (1, 'GAMBLING', 'NATIONAL LOTTERY', 4826),
#  (1, 'GAMBLING', 'WIREROOM/SPORTS', 4918),
#  (1, 'GAMBLING', 'BOOKMAKING/HORSES', 4936),
#  (0, 'SEX OFFENSE', 'ADULTRY', 4944),
#  (1, 'KIDNAPPING', 'UNLAWFUL INTERFERE/VISITATION', 4959),
#  (1, 'BATTERY', 'AGGRAVATED: OTHER FIREARM', 4968),
#  (1, 'GAMBLING', 'LOTTERY/OTHER', 4970),
#  (1, 'DECEPTIVE PRACTICE', 'PAY TV SERVICE OFFENSES', 5033),
#  (1, 'GAMBLING', 'BOLITA OR BOLI PUL/WRITER', 5046),
#  (0, 'GAMBLING', 'BOOKMAKING/HORSES', 5049),
#  (1, 'GAMBLING', 'SPORTS TAMPERING', 5082),
#  (0, 'GAMBLING', 'WIREROOM/SPORTS', 5150),
#  (0, 'WEAPONS VIOLATION', 'REGISTER OF SALES BY DEALER', 5162),
#  (1, 'GAMBLING', 'WIREROOM/HORSES', 5301),
#  (1, 'GAMBLING', 'BOLITA OR BOLI PUL/RUNNER', 5310),
#  (1, 'NARCOTICS', 'SALE/DEL HYPODERMIC NEEDLE', 5360),
#  (1, 'GAMBLING', 'POLICY/OTHER', 5494),
#  (0, 'GAMBLING', 'BOLITA OR BOLI PUL/OFFICE', 5692)]

# %% [markdown]
# <hr style="border-top: 5px solid green;" />
#
# ## BONUS QUESTIONS - You have the option to work through items 7 and 8 to receive extra-credit points - but extra-credit points will only be awarded after items 1-6 have been completed.  No bonus if items 1-6 are not faithfully attemtped.
#
# <hr style="border-top: 5px solid green;" />

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# ### 7 BONUS (10pts) -- Create a query that will retrieve two time series for crime count and arrest count per year from the database. Plot of these two time series in a single plot.

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# ### 8 BONUS (10pts) -- Develop a novel and useful query that could be potentially used for policing planning, policy making, citizen awareness, etc.
#
# Queries should provide some analytic value and insight into the Chicago crime data. Use your SQL skillset beyond simple SELECT-FROM-WHERE using multiple tables. Advanced solutions would include GROUP BY/HAVING, Nested Queries, Aggregation Operators, Window Functions, etc.
#
# Each query should have documentation to explain what this query is attempting to achieve and how it is meaningful and useful for analytic purposes and insight. Add your explanation to the markdown cell immeditely below.

# %% [markdown]
# ### 8 Documentation/Explanation Here

# %%
#Query Here

# %% [markdown]
# <hr style="border-top: 3px solid black;" />
#
# # Save your notebook, then `File > Close and Halt`
